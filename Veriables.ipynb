# %% [markdown]
# # Variables

# %% [markdown]
# ## 1. Defining variables (integers, floats, Booleans and strings)

# %% [markdown]
# > 👌 You can explore any Python variable with `help()` and `type()`

# %%
num = 3 # makes variable a and assigns value 2 to it

# %%
int('3')
# Out:
# 3

# %%
help(num)
# Out:
# Help on int object:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
# ...

# %%
b = 2.3

# %%
type(b)
# Out:
# float

# %%
c = num + b # you can assign operations on variables to other variables
c # in Deepnote you do not have to type print, you can simply type the name of the variable
# Out:
# 5.3

# %%
type(c)
# Out:
# float

# %%
d = -3.2
type(d)
# Out:
# float

# %%
ch = "a"

# %%
type(ch)
# Out:
# str

# %%
s = "Hello "

# %%
type(s)
# Out:
# str

# %%
my_sentence = s + 'Katia' #Concatenation
my_sentence
# Out:
# 'Hello Katia'

# %%
my_Boolean = True
type(my_Boolean)
# Out:
# bool

# %%
my_int = 4

# %% [markdown]
# ## 2. Rules for variable names
#
# - names can not start with a number
# - names can not contain spaces, use _ intead
# - names can not contain any of these symbols:
#     :'",<>/?|\!@#%^&*~-+
# - it's considered best practice ([PEP8](https://www.python.org/dev/peps/pep-0008/#function-and-variable-names)) that names are lowercase with underscores
# - you must not use Python built-in keywords like `list` and `str`
# - avoid using the single characters `l` (lowercase letter el), `O` (uppercase letter oh) and `I` (uppercase letter eye) as they can be confused with `1` and `0`

# %% [markdown]
# ## 🏋️🏋️ **In pairs** or individually 🏋️
#
# - rename variables above to follow Python naming rules
# - fix the bugs in code blocks below
# - create a variables that contains value 78 and find its data type
# - create a variables that contains value -78 and find its data type
# - create a variables that contains value 1.09 and find its data type
# - create a variables that contains value -1.09 and find its data type
# - create a string variable with your name

# %%
my_variable = True

# %%
four_the_love_of_code = "Hello world"

# %%
mine_and_yours = "Our budget"

# %%
my_string = "Hello world"

# %%
my_string = "Hello world"

# %%
my_string = "Hello world"

# %%
my_book = "Katia's book"

# %% [markdown]
# ## 3. Reassigning Variables
# Python lets you reassign variables.
#
# Python uses *dynamic typing*, meaning you can reassign variables to different data types. This makes Python flexible in assigning data types; it differs from languages that are *statically typed* and do no allow changing strings to integers.

# %%
my_integer = 6
my_integer = my_integer+1
my_integer
# Out:
# 7

# %%
my_number = 6
type(my_number)
# Out:
# int

# %%
my_number = my_number+0.5
type(my_number)
# Out:
# float

# %% [markdown]
# There are shortcuts for incrementing values. Python lets you add, subtract, multiply and divide numbers with reassignment using `+=`, `-=`, `*=`, and `/=`.

# %%
my_counter = 10
my_counter -= 1
my_counter -= 1
my_counter -= 1
my_counter -= 1
my_counter -= 1
my_counter
# Out:
# 5

# %% [markdown]
# ## 🏋️🏋️ **In pairs** or individually 🏋️
#
# - create variables length and width, calculate area and print it
# - create a string variable, change it into a Boolean

# %% [markdown]
# ## 3. Operations on strings

# %%
len('Hello World') #checks the length of a string
# Out:
# 11

# %%
greeting = 'Hello World'
len(greeting)
# Out:
# 11

# %%
greeting[0]
# Out:
# 'H'

# %%
greeting[2:] #Python has some really cool string slicing options: we will learn them later
# Out:
# 'llo World'

# %%
greeting[::-1]
# Out:
# 'dlroW olleH'

# %%
name = "alexei"
name.upper() # capitalises
# Out:
# 'ALEXEI'

# %%
name = "ALEXEI"
name.lower() # makes lower case
# Out:
# 'alexei'

# %%
name = "Alex"
greeting = "Privet, "
concatenated_message = greeting + name
concatenated_message
# Out:
# 'Privet, Alex'

# %%
first_num = "2"
second_num = "2"
print(first_num+second_num)
# Out:
# 22

# %%
first_num = "2"
second_num = "2"
print(int(first_num)+int(second_num)) # first converts to integers and then adds
# Out:
# 4

# %%
name = input("What is your name?")
print("Hello " + name)

# %%
name = input("What is your name?")
print("Hello " + name.upper() + "!")
# Out:
# Hello THEO!

# %%
apples = int(input("How many apples would you like?"))
print("🍎" * apples)
# Out:
# 🍎🍎🍎

# %% [markdown]
# ## 🏋️🏋️ **In pairs** or individually 🏋️
#
# - create a conversation that takes user input and prints something funny using the input

# %%
name = input("Hello, please enter your name")
print("Hi "+ name + " it is a plesure to meet you!")

phone = input("Please enter your phone number")
print("Thanks!")

request = input("what department would you like to speak to?")
print("Great! Someone from the " + request + (" department will call you on " + phone))

stars = int(input("Thank you for using this service, how many stars would you rate it?"))
print("Thank you for the " + ("⭐" * stars) + " If you wish to leave more feedback please visit the contact page on our website") * apples
# Out:
# Hi theo it is a plesure to meet you!
# Thanks!
# Great! Someone from the apple department will call you on 0294
# Thank you for the ⭐⭐⭐⭐ If you wish to leave more feedback please visit the contact page on our website
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_84/2856917953.py in <module>
#       9
#      10 stars = int(input("Thank you for using this service, how many stars would you rate it?"))
# ---> 11 print("Thank you for the " + ("⭐" * stars) + " If you wish to leave more feedback please visit the contact page on our website") * apples
#      12
#      13 print("Goodbye")
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'

# %%
request = input("what department would you like to speak to?")
print("Great! I will connect you to the " + request + ("department now"))

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9c19d2ba-3ff0-4eda-84b2-7e308ccb8d0b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
